# %% [markdown]
# ## Cleaning HTML content by stripping out HTML tags and converting HTML entities back to plain-text representations

# %%
from bs4 import BeautifulSoup # pip install beautifulsoup4

def cleanHtml(html):
    if html == "": return ""

    return BeautifulSoup(html, 'html5lib').get_text()

txt = "Don&#39;t forget about HTML entities and <strong>markup</strong> when "+\
      "mining text!<br />"

print(cleanHtml(txt))
# Out:
# Don't forget about HTML entities and markup when mining text!

# %% [markdown]
# ## Sample data structures used in illustrations for the rest of this chapter

# %%
corpus = {
 'a' : "Mr. Green killed Colonel Mustard in the study with the candlestick. \
Mr. Green is not a very nice fellow.",
 'b' : "Professor Plum has a green plant in his study.",
 'c' : "Miss Scarlett watered Professor Plum's green plant while he was away \
from his office last week."
}
terms = {
 'a' : [ i.lower() for i in corpus['a'].split() ], 
 'b' : [ i.lower() for i in corpus['b'].split() ],
 'c' : [ i.lower() for i in corpus['c'].split() ]
 }

# %% [markdown]
# ## Running TF-IDF on sample data

# %%
from math import log

# Enter in a query term from the corpus variable
QUERY_TERMS = ['mr.', 'green']

def tf(term, doc, normalize=True):
    doc = doc.lower().split()
    if normalize:
        return doc.count(term.lower()) / float(len(doc))
    else:
        return doc.count(term.lower()) / 1.0

def idf(term, corpus):
    num_texts_with_term = len([True for text in corpus if term.lower()
                              in text.lower().split()])

    # tf-idf calc involves multiplying against a tf value less than 0, so it's
    # necessary to return a value greater than 1 for consistent scoring.
    # (Multiplying two values less than 1 returns a value less than each of
    # them.)

    try:
        return 1.0 + log(float(len(corpus)) / num_texts_with_term)
    except ZeroDivisionError:
        return 1.0

def tf_idf(term, doc, corpus):
    return tf(term, doc) * idf(term, corpus)

corpus = \
    {'a': 'Mr. Green killed Colonel Mustard in the study with the candlestick. \
Mr. Green is not a very nice fellow.',
     'b': 'Professor Plum has a green plant in his study.',
     'c': "Miss Scarlett watered Professor Plum's green plant while he was away \
from his office last week."}

for (k, v) in sorted(corpus.items()):
    print(k, ':', v)
print()
    
# Score queries by calculating cumulative tf_idf score for each term in query

query_scores = {'a': 0, 'b': 0, 'c': 0}
for term in [t.lower() for t in QUERY_TERMS]:
    for doc in sorted(corpus):
        print('TF({0}): {1}'.format(doc, term), tf(term, corpus[doc]))
    print('IDF: {0}'.format(term), idf(term, corpus.values()))
    print()

    for doc in sorted(corpus):
        score = tf_idf(term, corpus[doc], corpus.values())
        print('TF-IDF({0}): {1}'.format(doc, term), score)
        query_scores[doc] += score
    print()

print("Overall TF-IDF scores for query '{0}'".format(' '.join(QUERY_TERMS)))
for (doc, score) in sorted(query_scores.items()):
    print(doc, score)
# Out:
# a : Mr. Green killed Colonel Mustard in the study with the candlestick. Mr. Green is not a very nice fellow.
# b : Professor Plum has a green plant in his study.
# c : Miss Scarlett watered Professor Plum's green plant while he was away from his office last week.
#
# TF(a): mr. 0.10526315789473684
# TF(b): mr. 0.0
# TF(c): mr. 0.0
# IDF: mr. 2.09861228866811
#
# TF-IDF(a): mr. 0.22090655670190631
# TF-IDF(b): mr. 0.0
# TF-IDF(c): mr. 0.0
#
# TF(a): green 0.10526315789473684
# TF(b): green 0.1111111111111111
# TF(c): green 0.0625
# IDF: green 1.0
#
# TF-IDF(a): green 0.10526315789473684
# TF-IDF(b): green 0.1111111111111111
# TF-IDF(c): green 0.0625
#
# Overall TF-IDF scores for query 'mr. green'
# a 0.3261697145966431
# b 0.1111111111111111
# c 0.0625

# %% [markdown]
# ## Exploring text data with NLTK

# %%
# Explore some of NLTK's functionality by exploring the data.
# Here are some suggestions for an interactive interpreter session.

import json
import nltk

# Download ancillary nltk packages if not already installed
nltk.download('stopwords')

# Load in human language data from wherever you've saved it
DATA = 'data/timoreilly.json'
data = json.loads(open(DATA).read())

# Combine titles and post content
all_content = " ".join([ i['title'] + " " + i['content'] for i in data ])

# Approximate bytes of text
print(len(all_content))

tokens = all_content.split()
text = nltk.Text(tokens)

# Examples of the appearance of the word "open"
text.concordance("open")

# Frequent collocations in the text (usually meaningful phrases)
text.collocations()

# Frequency analysis for words of interest
fdist = text.vocab()
print(fdist["open"])
print(fdist["source"])
print(fdist["web"])
print(fdist["2.0"])

# Number of words in the text
print('Number of tokens:', len(tokens))

# Number of unique words in the text
print('Number of unique words:', len(fdist.keys()))

# Common words that aren't stopwords
print('Common words that aren\'t stopwords')
print([w for w in list(fdist.keys())[:100]
   if w.lower() not in nltk.corpus.stopwords.words('english')])

# Long words that aren't URLs
print('Long words that aren\'t URLs')
print([w for w in fdist.keys() if len(w) > 15 and 'http' not in w])

# Number of URLs
print('Number of URLs: ',len([w for w in fdist.keys() if 'http' in w]))

# Top 10 Most Common Words
print('Top 10 Most Common Words')
print(fdist.most_common(10))
# Out:
# 131031
# Displaying 16 of 16 matches:
# , and how at least one team is using open source to let others see inside the
# ear that computational biologist and open science advocate (UC Berkeley profes
# ear that computational biologist and open science advocate (UC Berkeley profes
# : magazine slogan say, "If you can't open it, you don't own it." Predictive po
#  I'm proud to be a signatory to this open letter calling for this key policy i
# st, I've focused a lot on areas like open source software and the implications
# opic at greater length in my article Open Data and Algorithmic Regulation: htt
# cessful participatory projects, from open source software to wikis to social m
# ere isn't one (except that it's only open to US students - sorry. If anyone ha
# new contract that conformed with the open data mandate. If it were consistent
# If it were consistent with the Obama open data guidance, that RFP would requir
# ut of step with the administration’s open data policy.The founder of Hipcamp,
# is is a really important piece about open data and platforms. This is a really
# is is a really important piece about open data and platforms. Work on sh-t tha
# r. An excellent demonstration of why Open Access lowers the barriers to knowle
# .. An excellent demonstration of why Open Access lowers the barriers to knowle
# O'Reilly Media; New York; Cabo Pulmo; Bay Mini; East Bay; +Jennifer
# Pahlka; Silicon Valley; Brett Goldstein; Common Core; Maker Faire;
# worth reading.; NBC Press:Here; Nick Hanauer; Mini Maker; Next:Economy
# Summit; White House; income inequality.; weeks ago,; +Bryce Roberts;
# Bill Janeway
# 13
# 5
# 1
# 0
# Number of tokens: 21758
# Number of unique words: 5792
# Common words that aren't stopwords
# ['excellent', 'account', 'competitive', 'dynamics', 'shifting', "Lyft's", 'favor', 'ride...', 'ride-sharing', 'battle', 'Uber.', 'Unfortunately,', 'analysis', 'impact', 'autonomous', 'cars', 'shallow.', 'notes', 'vehicles', '"can', 'utilized', 'nearly', '100%', 'time."', 'Yet', 'one', 'key', 'drivers', 'peer-to-peer', 'model', 'pulls', 'part', 'time', 'workers', 'address', 'inherently', 'lumpy', 'demand.', 'enough', 'meet', 'peak', 'demand,', 'way', 'need.', '(I', 'talk', 'tradeoffs,', 'properly', 'understand', 'autonomy', 'intersects', 'on-demand', 'business', 'many', 'subjects', 'forthcoming', 'book', 'WTF:', "What's", 'Future', 'Us.)', 'Nonetheless,', 'must-read', 'article', 'game', 'changing', 'technology.', 'particularly']
# Long words that aren't URLs
# ['impossible.Technology', 'financialization,', 'collusion...could', 'transformative.)', 'public-relations', 'self-assessment...', 'self-assessment!', 'forward-thinking', '“attend-listen-embarrass”', 'algorithmically,', 'conversational...', '#OReillySecurity', '#makesecurityeasy', 'doing.Individually,', 'producers....Like', 'entrepreneurship', 'life-threatening', "Thursday.”That's", 'humansofnewyork.com', 'underrepresented', 'Republican-controlled', 'philanthropists,', 'Michener)quoteinvestigator.com/2010/08/27/master/Thanks', '“Areopagitica...', '#FutureCrimesConvo,', 'www.futurecrimes.com', 'statistics:"Typically,', 'Super-interesting.', 'Brothers...."Their', 'innovation-resistant', 'software...."Get', 'Ireland.Incidentally,', 'fundamentally...', 'level-headedness.', 'administration’s', 'jasonmking@fs.fed.us', 'Makers/Exhibitors/Performers,', 'Regulations?Evgeny', "backwards.Here's", 'opens:"Regulation', 'results."Consider,', 'outcome"Real-time', 'achieved"Algorithms', 'quasi-governmental', 'everyone"Adjustments', 'achieved"Contrast', 'condition."Lovely.And', 'opens:"Something’s', 'codeforamerica.org.', '@codeforamerica...', 'interoperability', 'customizability.', '(drnkwines.com),', 'stream-processing', 'investigation...', 'knowledge-sharing', 'Healthcare.govDraw', 'IndependenceThis', 'Palestinians:"This', 'national-authority', 'significantly."It']
# Number of URLs:  42
# Top 10 Most Common Words
# [('the', 1059), ('to', 624), ('of', 597), ('and', 515), ('a', 447), ('in', 334), ('is', 312), ('for', 264), ('I', 235), ('that', 226)]
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\GAO\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Querying text data with TF-IDF

# %%
import json
import nltk

# Provide your own query terms here

QUERY_TERMS = ['Government']

# Load in human language data from wherever you've saved it
DATA = 'data/timoreilly.json'
data = json.loads(open(DATA).read())

activities = [post['content'].lower().split() 
              for post in data 
                if post['content'] != ""]

# TextCollection provides tf, idf, and tf_idf abstractions so
# that we don't have to maintain/compute them ourselves

tc = nltk.TextCollection(activities)

relevant_activities = []

for idx in range(len(activities)):
    score = 0
    for term in [t.lower() for t in QUERY_TERMS]:
        score += tc.tf_idf(term, activities[idx])
    if score > 0:
        relevant_activities.append({'score': score, 'title': data[idx]['title']})

# Sort by score and display results

relevant_activities = sorted(relevant_activities,
                             key=lambda p: p['score'], reverse=True)
for activity in relevant_activities:
    print('Title: {0}'.format(activity['title']))
    print('Score: {0}'.format(activity['score']))
    print()
# Out:
# Title: Totally hilarious and spot-on. Has to be the best public service video ever done by a government office...
# Score: 0.10660131264074077
#
# Title: Excellent set of principles for digital government. Echoes those put forward by the UK Government and...
# Score: 0.10250126215455843
#
# Title: "We need to show every American competent government services they can actually use, services that treat...
# Score: 0.09517974342923281
#
# Title: If you're interested about the emerging startup ecosystem around government transformation (a $172 Billion...
# Score: 0.09189768331098341
#
# Title: I'm proud to be a judge for the new +Code for America tech awards. If you are doing something remarkable...
# Score: 0.08737812511536129
#
# Title: This is a wonderful analysis of a set of anti-patterns in enterprise software development. While it ...
# Score: 0.057935496000402584
#
# Title: Fundraiser for Libby Schaaf for Mayor of Oakland at the BlueSprout industrial co working space. Oakland...
# Score: 0.057935496000402584
#
# Title: This is what you get when you believe that “government should just get out of the way” and let industry...
# Score: 0.05028363803808526
#
# Title: I’ve been eagerly awaiting the public release of Steve Ballmer’s USAFacts project, and now it’s here...
# Score: 0.05028363803808526
#
# Title: Stories like this make me ashamed to be a US citizen.  We are abdicating our responsibility as citizens...
# Score: 0.045170047729127444
#
# Title: 9 days until SXSW Interactive: White House tech wiz Mikey Dickerson joins @pahlkadot on March 16 to ...
# Score: 0.044790467496109564
#
# Title: If we are going to transform government, we need both an inside game and an outside game.
#
# The inside...
# Score: 0.04275453715537732
#
# Title: UN Draft report on the use of data for sustainable development. It's very good already, but they are...
# Score: 0.03919165905909587
#
# Title: Bill Janeway provides powerful historical and economic context for the current state of world politics...
# Score: 0.037014344666923875
#
# Title: It's amazing to me that CGI, the company that brought us the healthcare.gov fiasco, has the chutzpah...
# Score: 0.03601395697322323
#
# Title:  +Maria Konnikova's NY Times article about the role of time and attention scarcity in the cycle of poverty...
# Score: 0.015722907469135804
#
# Title: Amazing story about digital transformation http://www.codeforamerica.org/blog/2015/11/30/a-new-approach...
# Score: 0.013528085360500096
#
# Title: This was my favorite piece in this Sunday's New York Times. It's a fascinating article about CBW, a ...
# Score: 0.008487365656109934
#
# Title: "Surely Democrats and Republicans could agree to cut billions from a failed program like this!" you ...
# Score: 0.007955321838861251

# %% [markdown]
# ## Finding similar documents using cosine similarity

# %%
import json
import nltk
import nltk.cluster

# Load in human language data from wherever you've saved it
DATA = 'data/timoreilly.json'
data = json.loads(open(DATA).read())

all_posts = [ (i['title'] + " " + i['content']).lower().split() for i in data ]

# Provides tf, idf, and tf_idf abstractions for scoring

tc = nltk.TextCollection(all_posts)

# Compute a term-document matrix such that td_matrix[doc_title][term]
# returns a tf-idf score for the term in the document

td_matrix = {}
for idx in range(len(all_posts)):
    post = all_posts[idx]
    fdist = nltk.FreqDist(post)

    doc_title = data[idx]['title'].replace('\n', '')
    td_matrix[doc_title] = {}

    for term in fdist.keys():
        td_matrix[doc_title][term] = tc.tf_idf(term, post)

# Build vectors such that term scores are in the same positions...
distances = {}
for title1 in td_matrix.keys():

    distances[title1] = {}
    (min_dist, most_similar) = (1.0, ('', ''))

    for title2 in td_matrix.keys():

        # Take care not to mutate the original data structures
        # since we're in a loop and need the originals multiple times

        terms1 = td_matrix[title1].copy()
        terms2 = td_matrix[title2].copy()

        # Fill in "gaps" in each map so vectors of the same length can be computed
        for term1 in terms1:
            if term1 not in terms2:
                terms2[term1] = 0

        for term2 in terms2:
            if term2 not in terms1:
                terms1[term2] = 0

        # Create vectors from term maps
        v1 = [score for (term, score) in sorted(terms1.items())]
        v2 = [score for (term, score) in sorted(terms2.items())]

        # Compute similarity amongst documents
        distances[title1][title2] = nltk.cluster.util.cosine_distance(v1, v2)

        if title1 == title2:
            #print distances[title1][title2]
            continue

        if distances[title1][title2] < min_dist:
            (min_dist, most_similar) = (distances[title1][title2], title2)

    print(u'Most similar (score: {})\n{}\n{}\n'.format(1-min_dist, title1, 
                                                       most_similar))
# Out:
# Most similar (score: 0.0971495885458028)
# This is an excellent account of how the competitive dynamics are shifting in Lyft's favor in its ride...
# As Jason Tanz of Wired, who urged me to write this piece, summarized its argument: "Uber was the product...
#
# Most similar (score: 0.09567029049269082)
# Billionaire Nick Hanauer has some blistering advice for his fellow plutocrats on the left. If you want...
# Nick Hanauer is so quotable. He talks “Trickle down clowns,” wage suppression, and corporate welfare...
#
# Most similar (score: 0.11319350317462973)
# Cheryl Platz, former senior UX designer on Amazon's Alexa platform team, recently spoke with O'Reilly...
# My thoughts on conversational interfaces, and why Alexa is now the market leader. If Siri, Google Now...
#
# Most similar (score: 0.15556848369037224)
# Brett Goldstein gives some excellent advice on basic security hygiene. It the most obvious cure for ...
# Worried about predictive policing? This profile of Civicscape and its co-founder Brett Goldstein will...
#
# Most similar (score: 0.10420138135351498)
# A couple of weeks ago, I sat down with New York Times senior editor Charles Duhigg at the Aspen Ideas...
# When I was in Spain a few weeks ago, I was struck by how beautiful the cacti could be, limned in light...
#
# Most similar (score: 0.17099733359325298)
# Carl Malamud explains that his crusade to make law and public safety codes free to the public online...
# The tragic Oakland fire is a strong argument for the importance of Carl Malamud's work to make building...
#
# Most similar (score: 0.11521742968329918)
# There are many directions this article could have gone - the difference in platform philosophy between...
# Who will build the “god platform” for the Internet of Things?The idea that everyone will have a separate...
#
# Most similar (score: 0.19748251884844026)
# Worried about predictive policing? This profile of Civicscape and its co-founder Brett Goldstein will...
# Predictive policing has enormous risks of introducing algorithmic bias. As a way of countering that,...
#
# Most similar (score: 0.13745312882932614)
# Read this brilliant pitch from Rob Reid about why Medium should become the new home for book authors...
# Mark Cuban's tweet about data science in the NBA, featuring the image of his screen and an O'Reilly ...
#
# Most similar (score: 0.0780058027330659)
# There's no better illustration of how the US has lost world leadership than when Chinese investors and...
# If  told you that any K-12 student in the US can get full access to all O'Reilly books and videos via...
#
# Most similar (score: 0.11457091356288118)
# If you live in New York, and you're not familiar with this book (and its followup, Secret New York: ...
# If you're interested about the emerging startup ecosystem around government transformation (a $172 Billion...
#
# Most similar (score: 0.11580664748350733)
# O'Reilly Media President Laura Baldwin explains the business rationale behind our decision to close ...
# October 30, at O'Reilly Media offices in Cambridge.  Docker seems to us to be one of the most important...
#
# Most similar (score: 0.0971495885458028)
# As Jason Tanz of Wired, who urged me to write this piece, summarized its argument: "Uber was the product...
# This is an excellent account of how the competitive dynamics are shifting in Lyft's favor in its ride...
#
# Most similar (score: 0.13343563348699927)
# If there is only one article about the NBA finals that you read, make it this one. And if you have no...
# A sobering read, especially when you walk around cities and still see people washing their cars and ...
#
# Most similar (score: 0.06602270253287423)
# This made me laugh out loud. One thing Trump has been good for is the rise of colorful commentary! "...
# This is the fascinating bit: "the rise of sharing economy companies follows rather than causes the bulk...
#
# Most similar (score: 0.12183902973806049)
# America’s class privilege runs much deeper than the “1%". We need to get rid of cherished middle class...
# I'm a huge fan of Dave Hickey, and this piece is well worth reading.
#
# Most similar (score: 0.10035528300654106)
# This is what you get when you believe that “government should just get out of the way” and let industry...
# If  told you that any K-12 student in the US can get full access to all O'Reilly books and videos via...
#
# Most similar (score: 0.08545041008691878)
# I wish I’d written this! It's the best explanation I've seen of how to think through the possible impact...
# The deep learning video collection from O'Reilly Media makes me wish I had more hours in the day. It's...
#
# Most similar (score: 0.10022359572638306)
# Bryce Roberts is doing an amazing job cutting through the hype and making clear the distinction between...
# I really like the way +Bryce Roberts explains why he chose the indie.vc companies:"It’s an experiment...
#
# Most similar (score: 0.05270062558117938)
# I had wondered what was the underlying truth being distorted in Trump's claims. This NYT article does...
# I'm really glad to see blame being put where it belongs: "When an unlucky passenger was violently dragged...
#
# Most similar (score: 0.07185295311814976)
# I'm really glad to see blame being put where it belongs: "When an unlucky passenger was violently dragged...
# Really great career advice here: "Getting off the “I should learn Python… someday” train and focusing...
#
# Most similar (score: 0.09793979448138956)
# Earlier this week, while I was in the UK, I was interviewed by @TPPodcast_ about tech, politics, and...
# Good summary of my CxO Talk interview last week, highlighting key points. And of course the entire hour...
#
# Most similar (score: 0.10202536038440768)
# I'm totally stoked to hear that computational biologist and open science advocate (UC Berkeley professor...
# Totally hilarious and spot-on. Has to be the best public service video ever done by a government office...
#
# Most similar (score: 0.1534169616961416)
# This is a good summary of one of those fresh ideas that will change the way you see the world and think...
# Good summary of my CxO Talk interview last week, highlighting key points. And of course the entire hour...
#
# Most similar (score: 0.07139814949838752)
# This is really great news. "In the Occidental vote, the world’s largest asset manager, BlackRock, for...
# Start-Up & Vote is a movement to encourage tech communities to vote early and vote together. Get a group...
#
# Most similar (score: 0.10437721842465608)
# Why do we treat assessments as “grades”? I'm proud that our team at +O'Reilly is providing self-assessment...
# I'm proud to be a judge for the new +Code for America tech awards. If you are doing something remarkable...
#
# Most similar (score: 0.09979859850269523)
# I'm so impressed with what Reid Hoffman and June Cohen have done with the #MastersOfScale podcast, so...
# How fragile life is, even for the best of us. We heard this morning that our friend Jake Brewer was ...
#
# Most similar (score: 0.10675793958498336)
# I love new sources of trend data about technology adoption. We've used variations of this for years ...
# This is a really important piece about open data and platforms.
#
# Most similar (score: 0.1258700361999504)
# So happy to see Code for America alum company Remix getting so much traction and a new round of funding...
# I wasn’t entirely happy with my new #NextEconomy piece, Escaping the Superstar Syndrome, so I updated...
#
# Most similar (score: 0.08760290519201142)
# The best thing about waitbutwhy’s story about Neuralink, Elon Musk's Brain-Machine Interface company...
# Wondering who designed, and who tested, the "improved" Google contacts interface (as displayed  in Chrome...
#
# Most similar (score: 0.06697691690551877)
# Here's an advance tidbit from tomorrow's Next:Economy newsletter. Sign up now to get the newsletter,...
# Beautiful exposition by Michael Nielsen on how “cognitive media” helps us think and advance our work...
#
# Most similar (score: 0.07096526330077801)
# I learned a lot from this analysis of the characteristics of high-performing CEOs, and how boards often...
# This is a wonderful analysis of a set of anti-patterns in enterprise software development. While it ...
#
# Most similar (score: 0.08085987881349377)
# I’ve been eagerly awaiting the public release of Steve Ballmer’s USAFacts project, and now it’s here...
# We just unveiled the project I've been working on for the past six months or so (really, the past couple...
#
# Most similar (score: 0.16954994453984706)
# This sequence of tweets from Dan Hon about the algorithmic fiasco at United is hilarious and insightful...
# Join Dan Dan Kaminsky for the #OReillySecurity hackathon happening now through the end of the week at...
#
# Most similar (score: 0.07336415268492669)
# This is an excellent piece on continuous delivery and business transformation at IBM, and the relationship...
# Why Common Core is Like Healthcare.govDraw a bold line between this piece on the failure of the Common...
#
# Most similar (score: 0.08278100805238864)
# This is the best piece I've read yet on the post-truth world, tongue-in-cheek yet full of truths to ...
# This is a very good explainer piece about filter bubbles on Facebook and Twitter and how they happen...
#
# Most similar (score: 0.13745312882932614)
# Mark Cuban's tweet about data science in the NBA, featuring the image of his screen and an O'Reilly ...
# Read this brilliant pitch from Rob Reid about why Medium should become the new home for book authors...
# Most similar (score: 0.07701722418511436)
# This is truly shameful. The DRM world has truly gone wild when a farmer is unable to fix his own equipment...
# This piece about how the pre-civil war south changed its justification for slavery over time is truly...
#
# Most similar (score: 0.19748251884844026)
# Predictive policing has enormous risks of introducing algorithmic bias. As a way of countering that,...
# Worried about predictive policing? This profile of Civicscape and its co-founder Brett Goldstein will...
#
# Most similar (score: 0.11126760278618619)
# This 1993 essay by Robert Putnam (who later wrote the classic book Bowling Alone) on social capital,...
# My new essay on what I've been calling "The WTF Economy." (In case you missed it, the first essay is...
#
# Most similar (score: 0.0988884044202013)
# As I discover old articles from +Hal Varian and interviews with him like this one, I'm always delighted...
# I like to think that O'Reilly books are always a great value, but when they go on special sale, like...
#
# Most similar (score: 0.11310252095109097)
# This is an excellent speech by the former US ambassador to Australia about the world today, ending with...
# This is a good summary of one of those fresh ideas that will change the way you see the world and think...
#
# Most similar (score: 0.08571582448925175)
# This is so true. A TRILLION dollar problem, but more than that, a tragedy of wasted - no destroyed -...
# Before you try to fix a problem, understand it. Saul Griffith and his team at Otherlab have done an ...
#
# Most similar (score: 0.08502634780775709)
# A populism based on love rather than fear? I’m all in! "Throughout his papacy, Francis has criticized...
# The Master in the Art of Living"The master in the art of living makes little distinction between his...
#
# Most similar (score: 0.06743792728497511)
# Wow! I thought I was strong on the topic in my forthcoming book, but David Hennemeier Hansen goes biblical...
# As Jason Tanz of Wired, who urged me to write this piece, summarized its argument: "Uber was the product...
#
# Most similar (score: 0.1508890560507048)
# ARPA-E is the Advanced Research Projects Agency for energy innovation. As you might expect, its funding...
# Before you try to fix a problem, understand it. Saul Griffith and his team at Otherlab have done an ...
#
# Most similar (score: 0.11439810746893375)
# So glad to see this conservative support for a carbon tax with the proceeds rebated to the public in...
# So Bill Gates thinks we need to 'science the shit' out of energy (and have a carbon tax.) So do I.
#
# Most similar (score: 0.08947389510901349)
# This account of a 1964 lecture by a neo-Nazi at UC Berkeley is an excellent explanation of free speech...
# This is an excellent account of how the competitive dynamics are shifting in Lyft's favor in its ride...
#
# Most similar (score: 0.06752016214042067)
# Wow. Steve Bannon is reading Halberstam's The Best and The Brightest, the book about the impetuous policies...
# Brilliant remarks by +Mikey D about what he learned from the healthcare.gov rescue and why he left Google...
#
# Most similar (score: 0.07643391279603107)
# This is a profoundly moving editorial from the Jordan Times about the parallels - and the differences...
# We just unveiled the project I've been working on for the past six months or so (really, the past couple...
#
# Most similar (score: 0.08879388171529112)
# I understand Google's goal of dealing with problems algorithmically, but this is shameful. Danny Sullivan...
# One reason I use f.lux on my mac, and wish it were available for all my devices...
#
# Most similar (score: 0.11010771844371703)
# Design is a key strategic advantage in times of technological change. Connected devices and conversational...
# Today is the last day! Submit a proposal for O'Reilly's Design Conference!
#
# Most similar (score: 0.09116981435409377)
# I am in awe both of the depth of Ta-nehisi Coates' insight and the beauty of his writing. This is a ...
# Well worth reading.  Typical Kevin Kelly insight and level-headedness.
#
# Most similar (score: 0.09653710382391689)
# How cool is it that the Dept of Commerce (Census Bureau and more) has Alexa skills! Congrats to Justin...
# Cool use of Minecraft for conservation!
#
# Most similar (score: 0.17099733359325298)
# The tragic Oakland fire is a strong argument for the importance of Carl Malamud's work to make building...
# Carl Malamud explains that his crusade to make law and public safety codes free to the public online...
#
# Most similar (score: 0.13358461793794607)
# "We need to show every American competent government services they can actually use, services that treat...
# It's amazing to me that CGI, the company that brought us the healthcare.gov fiasco, has the chutzpah...
#
# Most similar (score: 0.1737017048587295)
# Bill Janeway provides powerful historical and economic context for the current state of world politics...
# This piece by Bill Janeway should be required reading for anyone trying to understand the implications...
#
# Most similar (score: 0.1508890560507048)
# Before you try to fix a problem, understand it. Saul Griffith and his team at Otherlab have done an ...
# ARPA-E is the Advanced Research Projects Agency for energy innovation. As you might expect, its funding...
#
# Most similar (score: 0.07516272916927902)
# I love Andy Revkin’s idea for the “backtrack journal” - tracing the sources of things you see online...
# I love new sources of trend data about technology adoption. We've used variations of this for years ...
#
# Most similar (score: 0.15191357125308902)
# I like to think that O'Reilly books are always a great value, but when they go on special sale, like...
# Brilliant: "People turn to terrorism because they know they cannot wage war, so they opt instead to ...
#
# Most similar (score: 0.14732829871529596)
# What coverage of the Hamilton videos teaches us about the right way to protest, and the fake news problem...
# I reflect on how algorithms affect not just what news we consume, but what news is produced, and how...
#
# Most similar (score: 0.08278100805238864)
# This is a very good explainer piece about filter bubbles on Facebook and Twitter and how they happen...
# This is the best piece I've read yet on the post-truth world, tongue-in-cheek yet full of truths to ...
#
# Most similar (score: 0.07085738838496913)
# This story is personal and powerful: An incarcerated vet’s TEDx talk about how to end veteran suicide...
#  +Maria Konnikova's NY Times article about the role of time and attention scarcity in the cycle of poverty...
#
# Most similar (score: 0.2652697980149179)
# My Ride To Vote has created a crowdfunding campaign to fund a Get Out The Vote effort for Hillary in...
# Start-Up & Vote is a movement to encourage tech communities to vote early and vote together. Get a group...
#
# Most similar (score: 0.08884311192610461)
# Wow. " Using publicly available voter record data, VoteWithMe predicts the likelihood that contacts ...
# Wondering who designed, and who tested, the "improved" Google contacts interface (as displayed  in Chrome...
#
# Most similar (score: 0.14311020373881822)
# This is a wonderful analysis of a set of anti-patterns in enterprise software development. While it ...
# Excellent set of principles for digital government. Echoes those put forward by the UK Government and...
#
# Most similar (score: 0.05242725356305522)
# "It’s billions with a B,” said a cable executive, adding “there’s no business incentive to do so.” What's...
# Absolutely brilliant piece about complexity, public policy, and business From #NextEconomy speaker Esko...
#
# Most similar (score: 0.16954994453984706)
# Join Dan Dan Kaminsky for the #OReillySecurity hackathon happening now through the end of the week at...
# This sequence of tweets from Dan Hon about the algorithmic fiasco at United is hilarious and insightful...
#
# Most similar (score: 0.2652697980149179)
# Start-Up & Vote is a movement to encourage tech communities to vote early and vote together. Get a group...
# My Ride To Vote has created a crowdfunding campaign to fund a Get Out The Vote effort for Hillary in...
#
# Most similar (score: 0.1315136469006879)
# I was one of the warmup acts for President Obama at his Frontiers Conference on Science and Technology...
# A good example of why you can think of edge.org as TED in text form :-)  It's full of brilliant essays...
#
# Most similar (score: 0.07937345087192504)
# The Bob Dylan selection that Alexa gives me on my Echo in response to "Play Bob Dylan" is first rate...
# My thoughts on conversational interfaces, and why Alexa is now the market leader. If Siri, Google Now...
#
# Most similar (score: 0.08264690799031715)
# Chris O'Brien of Venturebeat did a great job of summarizing my exploration of technology and the future...
# My new post on Medium explains what I've been up to lately. I'm fascinated by how technology is driving...
# Most similar (score: 0.08474932973075999)
# Honored to be in this month's Wired, one of six people offering "advice to Silicon Valley" as part of...
# We just unveiled the project I've been working on for the past six months or so (really, the past couple...
#
# Most similar (score: 0.11218691214484589)
# From an article about Walmart, their move to pay more, and the lessons for the broader economy: http...
#  +Maria Konnikova's NY Times article about the role of time and attention scarcity in the cycle of poverty...
#
# Most similar (score: 0.0859466663369185)
# “I’m a science geek. I’m a nerd. And I don’t make any apologies for it.” That’s our @POTUS! (I'm so ...
# Mark Cuban's tweet about data science in the NBA, featuring the image of his screen and an O'Reilly ...
#
# Most similar (score: 0.11611910641911727)
# Here's a video excerpt from my keynote at the O'Reilly AI conference explaining one of the three reasons...
# I was one of the warmup acts for President Obama at his Frontiers Conference on Science and Technology...
#
# Most similar (score: 0.14732829871529596)
# I reflect on how algorithms affect not just what news we consume, but what news is produced, and how...
# What coverage of the Hamilton videos teaches us about the right way to protest, and the fake news problem...
#
# Most similar (score: 0.09954208198122338)
# Not registered to vote? Not sure what you need to do? VotePlz makes it easy to do the right thing. If...
# This is what you get when you believe that “government should just get out of the way” and let industry...
#
# Most similar (score: 0.078402223508799)
# This piece about how the pre-civil war south changed its justification for slavery over time is truly...
# This is a good summary of one of those fresh ideas that will change the way you see the world and think...
#
# Most similar (score: 0.11319350317462973)
# My thoughts on conversational interfaces, and why Alexa is now the market leader. If Siri, Google Now...
# Cheryl Platz, former senior UX designer on Amazon's Alexa platform team, recently spoke with O'Reilly...
#
# Most similar (score: 0.13212078043332276)
# I'm not usually a fan of formulas, but this is intriguing: 15 HigherEd Student Personas That Will Help...
# I'm a huge fan of Dave Hickey, and this piece is well worth reading.
#
# Most similar (score: 0.11806256129193649)
# I never know what I'm going to say when I start an interview. Here are two things I said recently to...
# I just did an hour video interview with +Slashdot. Here's what they had to say about it:"We've run...
#
# Most similar (score: 0.15191357125308902)
# Brilliant: "People turn to terrorism because they know they cannot wage war, so they opt instead to ...
# I like to think that O'Reilly books are always a great value, but when they go on special sale, like...
#
# Most similar (score: 0.09492075022925806)
# So what if the machines are so productive that they take away many of the jobs humans do today? There's...
# Lovely paean to the jobs of book collecting!This is what Milton means in his sublime “Areopagitica...
#
# Most similar (score: 0.12679067318570814)
# We've now opened registration for the second annual Next:Economy summit. Here is my post announcing ...
# Just published a narrative describing the nearly final schedule for the Next:Economy Summit. Hope to...
#
# Most similar (score: 0.11700991617212086)
# You've got to love this guy! So glad that he'll be a speaker at my Next:Economy Summit in October....
# Here are the slides from my talk at the Web Summit in Dublin.
#
# Most similar (score: 0.10209884467511299)
# Good piece about self driving cars and the disruption that Detroit is trying to embrace before it runs...
# This piece by Bill Janeway should be required reading for anyone trying to understand the implications...
#
# Most similar (score: 0.18199448794267314)
# If you love Hamilton, as I do, and you're interested in data visualization, you'll find this fascinating...
# If you're interested about the emerging startup ecosystem around government transformation (a $172 Billion...
#
# Most similar (score: 0.15920032961686226)
# Struck by how similar the investment model for Hamilton is to +Bryce Roberts Indie.vc model nyti.ms/...
# I really like the way +Bryce Roberts explains why he chose the indie.vc companies:"It’s an experiment...
#
# Most similar (score: 0.20475711631642446)
# The deep learning video collection from O'Reilly Media makes me wish I had more hours in the day. It's...
# Safari is O'Reilly's subscription access program - thousands of hours of video (including full video...
#
# Most similar (score: 0.08561345015170685)
# Smart piece by David Brin about the abuse of Adam Smith and Friedrich Hayek by their supposed followers...
# Who will build the “god platform” for the Internet of Things?The idea that everyone will have a separate...
#
# Most similar (score: 0.09567029049269082)
# Nick Hanauer is so quotable. He talks “Trickle down clowns,” wage suppression, and corporate welfare...
# Billionaire Nick Hanauer has some blistering advice for his fellow plutocrats on the left. If you want...
#
# Most similar (score: 0.08114696131183319)
# I wrote a short piece for Sloan Management Review about 21st century management. My thoughts strayed...
# Data can play a great role in advancing sustainability. I'm quoted in this short video from Planet Labs...
#
# Most similar (score: 0.07111056088433854)
# “Before Indie.vc, I was focused on raising a million dollars. Now I’m focused on generating a million...
# +Lawrence Lessig's MayDay PAC, a crowdfunded super PAC to end the influence of big money in politics...
#
# Most similar (score: 0.11332829220288754)
# Beautiful exposition by Michael Nielsen on how “cognitive media” helps us think and advance our work...
# I was on KQED Forum this morning, talking with Michael Krasny about technology and the future of work...
#
# Most similar (score: 0.21338419251735785)
# A lot of people have asked me to respond to +Paul Graham’s piece about income inequality. Here it is...
# Fascinating piece by Larry Summers about educational attainment and income inequality.  Not what you'd...
#
# Most similar (score: 0.2010743914070945)
# So nice to see @pahlkadot and @codeforamerica recognized by the 2016 David Packard Award for civic e...
# Here are the 2016 @codeforamerica Fellowship partner cities. Can’t wait to see the impact of these projects...
#
# Most similar (score: 0.14580716800215676)
# I've been deeply touched by the stories of Syrian refugees in Brandon Stanton's Humans of New York feed...
# I love that +Kickstarter  and the UN Refugee Agency are partnering to raise money for Syrian refugees...
#
# Most similar (score: 0.077849233277003)
# Excellent MIT Tech Review  profile of my friend Gary Marcus and his #AI company Geometric Intelligence...
# I wrote a short piece for Sloan Management Review about 21st century management. My thoughts strayed...
#
# Most similar (score: 0.1098613111401503)
# I'll be on the Breaking Banks podcast at noon pacific time today, talking about technology and the coming...
# I was on KQED Forum this morning, talking with Michael Krasny about technology and the future of work...
#
# Most similar (score: 0.06756098407969457)
# This is the fascinating bit: "the rise of sharing economy companies follows rather than causes the bulk...
# A populism based on love rather than fear? I’m all in! "Throughout his papacy, Francis has criticized...
#
# Most similar (score: 0.055972429103661736)
# I dreamed last night that Donald Trump was taking people on a tour through a haunted house, and leaving...
# This made me laugh out loud. One thing Trump has been good for is the rise of colorful commentary! "...
#
# Most similar (score: 0.12898495843241198)
# Nassau, The Bahamas Airport Travel AdviceIf anyone happens to travel to Nassau, the Bahamas, I thought...
# The other morning, before speaking at a Google event at Cavallo Point, +Jen Pahlka and I went for a ...
#
# Most similar (score: 0.09519362990836289)
# Amazing story about digital transformation http://www.codeforamerica.org/blog/2015/11/30/a-new-approach...
# Why Common Core is Like Healthcare.govDraw a bold line between this piece on the failure of the Common...
#
# Most similar (score: 0.14045353583708575)
# Cool use of Minecraft for conservation!
# This is a very cool demo by of musical programming from #OSCON.
#
# Most similar (score: 0.20475711631642446)
# Safari is O'Reilly's subscription access program - thousands of hours of video (including full video...
# The deep learning video collection from O'Reilly Media makes me wish I had more hours in the day. It's...
#
# Most similar (score: 0.07874586937950312)
# John Oliver: "There was only one time in American history when the fear of refugees wiping everyone ...
# I've been deeply touched by the stories of Syrian refugees in Brandon Stanton's Humans of New York feed...
#
# Most similar (score: 0.15954769022776372)
# Video learning paths have been a huge hit on oreilly.com. They are available on @safari too.
# My post explaining the in-progress redesign of oreilly.com.
#
# Most similar (score: 0.2010743914070945)
# Here are the 2016 @codeforamerica Fellowship partner cities. Can’t wait to see the impact of these projects...
# So nice to see @pahlkadot and @codeforamerica recognized by the 2016 David Packard Award for civic e...
#
# Most similar (score: 0.09774298852732599)
# Absolutely brilliant piece about complexity, public policy, and business From #NextEconomy speaker Esko...
# You've got to love this guy! So glad that he'll be a speaker at my Next:Economy Summit in October....
# Most similar (score: 0.07605579996030032)
# Portable benefits tied to the worker, not the company, are key to rethinking the social safety net for...
# Carl Malamud explains that his crusade to make law and public safety codes free to the public online...
#
# Most similar (score: 0.11332829220288754)
# I was on KQED Forum this morning, talking with Michael Krasny about technology and the future of work...
# Beautiful exposition by Michael Nielsen on how “cognitive media” helps us think and advance our work...
#
# Most similar (score: 0.07274638984979698)
# I just finished my product hunt AMA. I wrote quite a bit, on a lot of topics! https://www.producthunt.com...
# I wrote a short piece for Sloan Management Review about 21st century management. My thoughts strayed...
#
# Most similar (score: 0.08506584251224603)
# I loved this piece! Why companies invest in the future, and why nations should do so too.
# Video learning paths have been a huge hit on oreilly.com. They are available on @safari too.
#
# Most similar (score: 0.11258872054331381)
# I'm doing a ProductHunt AMA at 9 am PT this morning.  I love getting people thinking harder about how...
# My new post on Medium explains what I've been up to lately. I'm fascinated by how technology is driving...
#
# Most similar (score: 0.12679067318570814)
# Just published a narrative describing the nearly final schedule for the Next:Economy Summit. Hope to...
# We've now opened registration for the second annual Next:Economy summit. Here is my post announcing ...
#
# Most similar (score: 0.0709925814823128)
# This is a wonderful meditation by Walter Isaacson on the role of imagination in science, on the 100th...
# This is a wonderful analysis of a set of anti-patterns in enterprise software development. While it ...
#
# Most similar (score: 0.1258700361999504)
# I wasn’t entirely happy with my new #NextEconomy piece, Escaping the Superstar Syndrome, so I updated...
# So happy to see Code for America alum company Remix getting so much traction and a new round of funding...
#
# Most similar (score: 0.10694857344718023)
# Totally hilarious and spot-on. Has to be the best public service video ever done by a government office...
# This sequence of tweets from Dan Hon about the algorithmic fiasco at United is hilarious and insightful...
#
# Most similar (score: 0.09152998372508847)
# It's easy to think that the technology revolution that started in Silicon Valley doesn't apply to your...
# A couple of weeks ago, I sat down with New York Times senior editor Charles Duhigg at the Aspen Ideas...
#
# Most similar (score: 0.11439810746893375)
# So Bill Gates thinks we need to 'science the shit' out of energy (and have a carbon tax.) So do I.
# So glad to see this conservative support for a carbon tax with the proceeds rebated to the public in...
#
# Most similar (score: 0.0951725922678619)
# One reason I use f.lux on my mac, and wish it were available for all my devices...
# The deep learning video collection from O'Reilly Media makes me wish I had more hours in the day. It's...
#
# Most similar (score: 0.08548612226009811)
# I explain to Emily Chang at Bloomberg the urgency of the issues that I'm wrestling with in my Next:Economy...
# You've got to love this guy! So glad that he'll be a speaker at my Next:Economy Summit in October....
#
# Most similar (score: 0.2703310388496172)
# Crate stacking is hard! (At least for me.) But there's so much other great stuff at East Bay Mini Maker...
# If you aren't planning to come to East Bay Mini Maker Faire in Oakland tomorrow, here are 170 reasons...
#
# Most similar (score: 0.6205617182457673)
# Part One of my NBC Press:Here TV interview from Friday. I talk about the history and mission of O'Reilly...
# Part Two of my NBC Press:Here TV interview from
#
# Most similar (score: 0.6205617182457673)
# Part Two of my NBC Press:Here TV interview from
# Part One of my NBC Press:Here TV interview from Friday. I talk about the history and mission of O'Reilly...
#
# Most similar (score: 0.15549304349931603)
# "Surely Democrats and Republicans could agree to cut billions from a failed program like this!" you ...
# Can We Use Data to Make Better Regulations?Evgeny Morozov either misunderstands or misrepresents the...
#
# Most similar (score: 0.14580716800215676)
# I love that +Kickstarter  and the UN Refugee Agency are partnering to raise money for Syrian refugees...
# I've been deeply touched by the stories of Syrian refugees in Brandon Stanton's Humans of New York feed...
#
# Most similar (score: 0.1268832882361317)
# Data can play a great role in advancing sustainability. I'm quoted in this short video from Planet Labs...
# Fascinating look at the role that various US billionaires play in politics. A quick look at what appears...
#
# Most similar (score: 0.08788567111746903)
# This story of Afghan “aid” highlights how often cupidity and political theater overrule strategic goals...
# What coverage of the Hamilton videos teaches us about the right way to protest, and the fake news problem...
#
# Most similar (score: 0.1465012283160756)
# My latest post on Medium. I describe what makes a real unicorn. Hint: It's not the valuation.
# Just published the latest in my #WTFEconomy (What's the Future of Work) series of essays on Medium. ...
#
# Most similar (score: 0.11123743717144774)
# How fragile life is, even for the best of us. We heard this morning that our friend Jake Brewer was ...
# Who will build the “god platform” for the Internet of Things?The idea that everyone will have a separate...
#
# Most similar (score: 0.23812889221985012)
# Just published the latest in my #WTFEconomy (What's the Future of Work) series of essays on Medium. ...
# Here is the latest in my #WTFeconomy  series of posts on Medium. (Earlier posts include The WTF Economy...
#
# Most similar (score: 0.09186902884882875)
# Neil Gaiman is a magical writer. This is a fabulous opportunity to own DRM-free ebooks by Neil, with...
# Fabulous read from Thomas Piketty on Germany's own history of debt relief, vs its current stance towards...
#
# Most similar (score: 0.08097309793501084)
# So good: "Overwork is not defined by the amount of our day work occupies but by the amount of our selves...
# How fragile life is, even for the best of us. We heard this morning that our friend Jake Brewer was ...
#
# Most similar (score: 0.23812889221985012)
# Here is the latest in my #WTFeconomy  series of posts on Medium. (Earlier posts include The WTF Economy...
# Just published the latest in my #WTFEconomy (What's the Future of Work) series of essays on Medium. ...
#
# Most similar (score: 0.07112118500923925)
# This just in from my friend +Brian Forde:"A couple of weeks ago we announced $75,000 in scholarships...
# A couple of weeks ago, I sat down with New York Times senior editor Charles Duhigg at the Aspen Ideas...
#
# Most similar (score: 0.09340669603706875)
# Lovely quote from Wallace Stevens: "“One may find intimations of immortality in an object on the mantelpiece...
# Lovely paean to the jobs of book collecting!This is what Milton means in his sublime “Areopagitica...
#
# Most similar (score: 0.11126760278618619)
# My new essay on what I've been calling "The WTF Economy." (In case you missed it, the first essay is...
# This 1993 essay by Robert Putnam (who later wrote the classic book Bowling Alone) on social capital,...
#
# Most similar (score: 0.08901591406618592)
# Love this from +Liza Daly: "If you have a responsibility for hiring people, at any level, you have one...
# This is a good summary of one of those fresh ideas that will change the way you see the world and think...
#
# Most similar (score: 0.14311020373881822)
# Excellent set of principles for digital government. Echoes those put forward by the UK Government and...
# This is a wonderful analysis of a set of anti-patterns in enterprise software development. While it ...
#
# Most similar (score: 0.11010771844371703)
# Today is the last day! Submit a proposal for O'Reilly's Design Conference!
# Design is a key strategic advantage in times of technological change. Connected devices and conversational...
#
# Most similar (score: 0.19765393223098848)
# My new post on Medium explains what I've been up to lately. I'm fascinated by how technology is driving...
# Super-interesting. I am fascinated by the possibilities.
#
# Most similar (score: 0.0861807300487063)
# I was inspired to think differently when I read Barbara Ehrenreich's Nickel and Dimed in America. If...
# A good example of why you can think of edge.org as TED in text form :-)  It's full of brilliant essays...
#
# Most similar (score: 0.07596962313558897)
# I love the quote from Hesiod, Works and Days: “The gods keep livelihood hidden from men. Otherwise a...
# Lovely quote from Wallace Stevens: "“One may find intimations of immortality in an object on the mantelpiece...
#
# Most similar (score: 0.12314631816466182)
# If you haven't checked out Safari lately (O'Reilly Media's online learning service, whose name predates...
# The deep learning video collection from O'Reilly Media makes me wish I had more hours in the day. It's...
# Most similar (score: 0.09619608731392326)
# We just unveiled the project I've been working on for the past six months or so (really, the past couple...
# If we are going to transform government, we need both an inside game and an outside game.The inside...
#
# Most similar (score: 0.09186902884882875)
# Fabulous read from Thomas Piketty on Germany's own history of debt relief, vs its current stance towards...
# Neil Gaiman is a magical writer. This is a fabulous opportunity to own DRM-free ebooks by Neil, with...
#
# Most similar (score: 0.10743139258327883)
# Wondering who designed, and who tested, the "improved" Google contacts interface (as displayed  in Chrome...
# Who will build the “god platform” for the Internet of Things?The idea that everyone will have a separate...
#
# Most similar (score: 0.22812675586370013)
# Just discovered (via Laszlo Bock's Work Rules) a fabulous essay by Henry Ford explaining why it's important...
# The Master in the Art of Living"The master in the art of living makes little distinction between his...
#
# Most similar (score: 0.07344672679241959)
# A very good piece by +Sean Parker about "Hacker Philanthropy."  How the tech generation can and should...
# UN Draft report on the use of data for sustainable development. It's very good already, but they are...
#
# Most similar (score: 0.0856129639089176)
# Does Pope Francis look gloomy to you?This is a brilliant, funny takedown of the conservative Catholic...
# So glad to see this conservative support for a carbon tax with the proceeds rebated to the public in...
#
# Most similar (score: 0.10437721842465608)
# I'm proud to be a judge for the new +Code for America tech awards. If you are doing something remarkable...
# Why do we treat assessments as “grades”? I'm proud that our team at +O'Reilly is providing self-assessment...
#
# Most similar (score: 0.069611158230373)
# Congratulations to @dalepd, @gbrockway and the whole @make Team on the new financing. And welcome aboard...
# If  told you that any K-12 student in the US can get full access to all O'Reilly books and videos via...
#
# Most similar (score: 0.09577098859552802)
# Brilliant post by @JonBruner on why the new hardware movement is way bigger than the #IoT. A must-read...
# My new post on Medium explains what I've been up to lately. I'm fascinated by how technology is driving...
#
# Most similar (score: 0.15920032961686226)
# I really like the way +Bryce Roberts explains why he chose the indie.vc companies:"It’s an experiment...
# Struck by how similar the investment model for Hamilton is to +Bryce Roberts Indie.vc model nyti.ms/...
#
# Most similar (score: 0.06028337484478852)
# Matt Cutts, for so long the most human face of Google, and a wonderful human being. In the halls at ...
# This is a wonderful analysis of a set of anti-patterns in enterprise software development. While it ...
#
# Most similar (score: 0.1534169616961416)
# Good summary of my CxO Talk interview last week, highlighting key points. And of course the entire hour...
# This is a good summary of one of those fresh ideas that will change the way you see the world and think...
#
# Most similar (score: 0.1737017048587295)
# This piece by Bill Janeway should be required reading for anyone trying to understand the implications...
# Bill Janeway provides powerful historical and economic context for the current state of world politics...
#
# Most similar (score: 0.06998320160262617)
# Brilliant and important!"What we have, uniquely in America, is a political class, and an entire political...
# This was my favorite piece in this Sunday's New York Times. It's a fascinating article about CBW, a ...
#
# Most similar (score: 0.045529766172355046)
# I like how Evan thinks. Smart, and with good values.
# I like to think that O'Reilly books are always a great value, but when they go on special sale, like...
#
# Most similar (score: 0.1315136469006879)
# A good example of why you can think of edge.org as TED in text form :-)  It's full of brilliant essays...
# I was one of the warmup acts for President Obama at his Frontiers Conference on Science and Technology...
#
# Most similar (score: 0.13942525269424)
# Encourage your local superintendent to get involved!
# Start-Up & Vote is a movement to encourage tech communities to vote early and vote together. Get a group...
#
# Most similar (score: 0.22812675586370013)
# The Master in the Art of Living"The master in the art of living makes little distinction between his...
# Just discovered (via Laszlo Bock's Work Rules) a fabulous essay by Henry Ford explaining why it's important...
#
# Most similar (score: 0.15954769022776372)
# My post explaining the in-progress redesign of oreilly.com.
# Video learning paths have been a huge hit on oreilly.com. They are available on @safari too.
#
# Most similar (score: 0.09668243743674099)
# Painting by Jeannette Charoy at Pamil Fine Arts. Love this one. Thanks for showing it to us, Giancarlo...
# Is anyone else having troubles with Bluetooth on a Moto X?  It connects fine to my car when I make a...
#
# Most similar (score: 0.09492075022925806)
# Lovely paean to the jobs of book collecting!This is what Milton means in his sublime “Areopagitica...
# So what if the machines are so productive that they take away many of the jobs humans do today? There's...
#
# Most similar (score: 0.09848445507111137)
# Morning run at Lake MerrittFive more reasons to love living in Oakland.
# Here's a video excerpt from my keynote at the O'Reilly AI conference explaining one of the three reasons...
#
# Most similar (score: 0.07883325547855657)
# "You can add up all the yearly visitors to the city's baseball stadiums, its basketball and hockey arenas...
# +Jennifer Pahlka has some visitors during lunch on our first day hiking the Inca Trail last week.
#
# Most similar (score: 0.17498929952738962)
# +Jennifer Pahlka and I share a moment of joy at the top of Warmiwanuska Pass, the highest point on the...
# +Jennifer Pahlka has some visitors during lunch on our first day hiking the Inca Trail last week.
#
# Most similar (score: 0.16025744738654635)
# Zach Bogue - here I am wearing my Founder's Den t-shirt while hiking the Inca Trail!
# +Jennifer Pahlka has some visitors during lunch on our first day hiking the Inca Trail last week.
#
# Most similar (score: 0.17498929952738962)
# +Jennifer Pahlka has some visitors during lunch on our first day hiking the Inca Trail last week.
# +Jennifer Pahlka and I share a moment of joy at the top of Warmiwanuska Pass, the highest point on the...
#
# Most similar (score: 0.05807991956198222)
# Utterly magnificent views on the hike up from Urubamba to Maras.
# "You can add up all the yearly visitors to the city's baseball stadiums, its basketball and hockey arenas...
#
# Most similar (score: 0.04507839096761901)
# That's a heck of a collection! Clever idea to display their impounded blades!
# Who will build the “god platform” for the Internet of Things?The idea that everyone will have a separate...
#
# Most similar (score: 0.07807772698471893)
# Texas has nothing on Peru. They like their Coca-Cola big down here!
# I like to think that O'Reilly books are always a great value, but when they go on special sale, like...
#
# Most similar (score: 0.08506276193387052)
# Brilliant remarks by +Mikey D about what he learned from the healthcare.gov rescue and why he left Google...
# Absolutely brilliant piece about complexity, public policy, and business From #NextEconomy speaker Esko...
#
# Most similar (score: 0.21338419251735785)
# Fascinating piece by Larry Summers about educational attainment and income inequality.  Not what you'd...
# A lot of people have asked me to respond to +Paul Graham’s piece about income inequality. Here it is...
#
# Most similar (score: 0.13442224863990593)
# My latest @radar post: #SocialCivics and the architecture of participation. Inspired by @goldman joining...
# Help O'Reilly Media learn more about software architecture roles by completing a short industry survey...
#
# Most similar (score: 0.07663520842113503)
# My dear friend Carolyn Shapiro does amazing projects that help communities understand their history,...
# Who will build the “god platform” for the Internet of Things?The idea that everyone will have a separate...
#
# Most similar (score: 0.08019984772667943)
# It is amazing to see trees in full bloom in Vancouver in March. Many of them are in fact past their ...
# We just unveiled the project I've been working on for the past six months or so (really, the past couple...
#
# Most similar (score: 0.09032311670082305)
# 9 days until SXSW Interactive: White House tech wiz Mikey Dickerson joins @pahlkadot on March 16 to ...
# I reflect on how algorithms affect not just what news we consume, but what news is produced, and how...
#
# Most similar (score: 0.042300443723047754)
# I like +Nancy Lublin's pineapple hack. #LeanInTogether
# I like to think that O'Reilly books are always a great value, but when they go on special sale, like...
#
# Most similar (score: 0.12271923433402354)
# There are two kinds of interviews: those that quote you literally, and those that distill the essence...
# This is a good summary of one of those fresh ideas that will change the way you see the world and think...
#
# Most similar (score: 0.09242557769869642)
# What a great read!  @neilhimself explains why our future depends on libraries, reading and daydreaming...
# O'Reilly Media President Laura Baldwin explains the business rationale behind our decision to close ...
# Most similar (score: 0.13442224863990593)
# Help O'Reilly Media learn more about software architecture roles by completing a short industry survey...
# My latest @radar post: #SocialCivics and the architecture of participation. Inspired by @goldman joining...
#
# Most similar (score: 0.1630682528257139)
# Just about to go on with Marc Goodman (@futurecrimes) for a discussion of his book Future Crimes starting...
# I'm going to be doing a google hangout this Thursday, February 26 at 1 pm Pacific, with Marc Goodman...
#
# Most similar (score: 0.1630682528257139)
# I'm going to be doing a google hangout this Thursday, February 26 at 1 pm Pacific, with Marc Goodman...
# Just about to go on with Marc Goodman (@futurecrimes) for a discussion of his book Future Crimes starting...
#
# Most similar (score: 0.07260659116850665)
# Really great career advice here: "Getting off the “I should learn Python… someday” train and focusing...
# I have been really impressed by Howard Schultz of @starbucks. Really looking forward to his new book...
#
# Most similar (score: 0.08128250823847283)
# Neville Chamberlin, Winston Churchill, and climate change. A good reminder to politicians about the ...
# I find it distressing that US politicians (and the rest of world governments) can find hundreds of billions...
#
# Most similar (score: 0.2218410641053642)
# Santa Fe sunset
# Last Cabo Pulmo sunset of this holiday. Spectacular!
#
# Most similar (score: 0.0956148817588034)
# Absolutely fascinating exploration of the microbiome of a city.For those who don't know what the microbiome...
# I never know what I'm going to say when I start an interview. Here are two things I said recently to...
#
# Most similar (score: 0.07788075660434512)
# Fascinating history of the lobbying campaign that took streets away from pedestrians and gave them to...
# Part One of my NBC Press:Here TV interview from Friday. I talk about the history and mission of O'Reilly...
#
# Most similar (score: 0.19765393223098848)
# Super-interesting. I am fascinated by the possibilities.
# My new post on Medium explains what I've been up to lately. I'm fascinated by how technology is driving...
#
# Most similar (score: 0.0743426641977466)
# The best definition of Freudian psychoanalysis I've ever seen, from poet W.H. Auden:"...he merely ...
# ...
# The deep learning video collection from O'Reilly Media makes me wish I had more hours in the day. It's...
#
# Most similar (score: 0.44617481825328786)
# Cabo Pulmo sunrise
# Last Cabo Pulmo sunset of this holiday. Spectacular!
#
# Most similar (score: 0.16645193405431125)
# If  told you that any K-12 student in the US can get full access to all O'Reilly books and videos via...
# Safari is O'Reilly's subscription access program - thousands of hours of video (including full video...
#
# Most similar (score: 0.09732746877160614)
# Inside La Sagrada Familia, Gaudi's "Church of Harmonious Light."  The colors and shapes are astonishing...
# If we are going to transform government, we need both an inside game and an outside game.The inside...
#
# Most similar (score: 0.08652850821144631)
# I like Michael Lewis' latest piece, about how happiness comes more from giving than from getting more...
# I wasn’t entirely happy with my new #NextEconomy piece, Escaping the Superstar Syndrome, so I updated...
#
# Most similar (score: 0.07747434397861308)
# Johnny McGuire, the owner of the wonderful Bricin restaurant in Killarney, told me how moved he was ...
# Back now from a wonderful holiday in Ireland.  It included a "Hawk Walk" in Killarney with Killarney...
#
# Most similar (score: 0.07407012255090584)
# This piece about @jgrahamc's campaign to get the UK gov to apologize to Alan Turing shows why +Steven...
# Fascinating history of the lobbying campaign that took streets away from pedestrians and gave them to...
#
# Most similar (score: 0.1912748055663297)
# And here's a view of Loch Leine, from the same spot in Killarney.
# View of Torc, which rises over Muckross Lake, from atop a ruin in Killarney. Stunning!I grew up with...
#
# Most similar (score: 0.1912748055663297)
# View of Torc, which rises over Muckross Lake, from atop a ruin in Killarney. Stunning!I grew up with...
# And here's a view of Loch Leine, from the same spot in Killarney.
#
# Most similar (score: 0.08677466614318508)
# Advice on speechwriting from my 80+ year old Irish aunt: "Try to write a very good first line. And then...
# Nassau, The Bahamas Airport Travel AdviceIf anyone happens to travel to Nassau, the Bahamas, I thought...
#
# Most similar (score: 0.07174253885013815)
# At Bolton Abbey in Yorkshire, a compelling reminder that the beloved landscape of Yorkshire is fundamentally...
# Neville Chamberlin, Winston Churchill, and climate change. A good reminder to politicians about the ...
#
# Most similar (score: 0.1231803076454)
# Super exciting news for O'Reilly and Safari. Even more great technical training content coming soon!
# I reflect on how algorithms affect not just what news we consume, but what news is produced, and how...
#
# Most similar (score: 0.11700991617212086)
# Here are the slides from my talk at the Web Summit in Dublin.
# You've got to love this guy! So glad that he'll be a speaker at my Next:Economy Summit in October....
#
# Most similar (score: 0.18199448794267314)
# If you're interested about the emerging startup ecosystem around government transformation (a $172 Billion...
# If you love Hamilton, as I do, and you're interested in data visualization, you'll find this fascinating...
#
# Most similar (score: 0.09046551567459526)
# The programmable world is creating disruptive innovation as profound as the Internet . A good place ...
# This is a good summary of one of those fresh ideas that will change the way you see the world and think...
#
# Most similar (score: 0.26504543580680684)
# Well worth reading.  Typical Kevin Kelly insight and level-headedness.
# I'm a huge fan of Dave Hickey, and this piece is well worth reading.
#
# Most similar (score: 0.1520102176972684)
# Important piece about why the "tradeoff" between security and privacy will inevitably end badly...
# This is a really important piece about open data and platforms.
#
# Most similar (score: 0.11327706147949845)
# Every teacher in the modern world should read this piece, and do what the author did.
# I wasn’t entirely happy with my new #NextEconomy piece, Escaping the Superstar Syndrome, so I updated...
# Most similar (score: 0.09506853753609978)
# UN Draft report on the use of data for sustainable development. It's very good already, but they are...
# This is a wonderful analysis of a set of anti-patterns in enterprise software development. While it ...
#
# Most similar (score: 0.1449467578691045)
# I have been really impressed by Howard Schultz of @starbucks. Really looking forward to his new book...
# This is a really important piece about open data and platforms.
#
# Most similar (score: 0.12344099929311458)
# The 10-year contract for the US recreation.gov site  is up for renewal, and the Department of the Interior...
# This is a really important piece about open data and platforms.
#
# Most similar (score: 0.40490942627538984)
# If you aren't planning to come to East Bay Mini Maker Faire in Oakland tomorrow, here are 170 reasons...
# It's wonderful to see the program shaping up for the East Bay Mini Maker Faire in Oakland next Sunday...
#
# Most similar (score: 0.046250219654023206)
# Fun tile work in bryant park subway station
# If you aren't planning to come to East Bay Mini Maker Faire in Oakland tomorrow, here are 170 reasons...
#
# Most similar (score: 0.12549451157333702)
# October 30, at O'Reilly Media offices in Cambridge.  Docker seems to us to be one of the most important...
# The view from the offices of Passport Capital at One Market. Amazing how much construction is happening...
#
# Most similar (score: 0.04254844876805164)
# It's a mob scene in the #strataconf exhibit hall.
# It's almost fireworks time in Tulsa!
#
# Most similar (score: 0.08716266336109135)
# My family includes vaccine deniers.  This one is for them, and for far too many others. Funny how fear...
# Safari is O'Reilly's subscription access program - thousands of hours of video (including full video...
#
# Most similar (score: 0.13343563348699927)
# A sobering read, especially when you walk around cities and still see people washing their cars and ...
# If there is only one article about the NBA finals that you read, make it this one. And if you have no...
#
# Most similar (score: 0.40490942627538984)
# It's wonderful to see the program shaping up for the East Bay Mini Maker Faire in Oakland next Sunday...
# If you aren't planning to come to East Bay Mini Maker Faire in Oakland tomorrow, here are 170 reasons...
#
# Most similar (score: 0.15549304349931603)
# Can We Use Data to Make Better Regulations?Evgeny Morozov either misunderstands or misrepresents the...
# "Surely Democrats and Republicans could agree to cut billions from a failed program like this!" you ...
#
# Most similar (score: 0.08015459995674634)
# Homework: An Unnecessary EvilAlfie Kohn's first footnote perfectly captures my feelings (although ...
# Can We Use Data to Make Better Regulations?Evgeny Morozov either misunderstands or misrepresents the...
#
# Most similar (score: 0.0427310419690784)
# What is not to love?! “@edabot: Chocolate millennium falcon made w help from #othermill @othermill +...
# This made me laugh out loud. One thing Trump has been good for is the rise of colorful commentary! "...
#
# Most similar (score: 0.10389318110715073)
# Marilynne Robinson's Gilead is one of my favorite books ever.  I have re-read some passages dozens of...
# I just did an hour video interview with +Slashdot. Here's what they had to say about it:"We've run...
#
# Most similar (score: 0.1198548426637629)
# I'm bummed I had a conflict and couldn't be there for the moment!  Governor Jerry Brown endorses my ...
# Fundraiser for Libby Schaaf for Mayor of Oakland at the BlueSprout industrial co working space. Oakland...
#
# Most similar (score: 0.09065554922722852)
# Actually, I think this shot is better.
# I'm so impressed with what Reid Hoffman and June Cohen have done with the #MastersOfScale podcast, so...
#
# Most similar (score: 0.15634099832796367)
# The other morning, before speaking at a Google event at Cavallo Point, +Jen Pahlka and I went for a ...
# Cabo Pulmo sunrise
#
# Most similar (score: 0.08710009988626533)
# Google's Atmosphere event livecast starts tomorrow morning at 8:45 am pacific.  I'll be there, along...
# The other morning, before speaking at a Google event at Cavallo Point, +Jen Pahlka and I went for a ...
#
# Most similar (score: 0.1053852568826994)
# My latest blog post:  What Amazon, iTunes, and Uber Teach Us About Apple Pay.The post opens:"Something’s...
# Who will build the “god platform” for the Internet of Things?The idea that everyone will have a separate...
#
# Most similar (score: 0.1520102176972684)
# This is a really important piece about open data and platforms.
# Important piece about why the "tradeoff" between security and privacy will inevitably end badly...
#
# Most similar (score: 0.07762978287256861)
# Work on sh-t that matters, aka Poo CampToday was the annual chicken coop poo cleanup. (The chickens...
# How fragile life is, even for the best of us. We heard this morning that our friend Jake Brewer was ...
#
# Most similar (score: 0.12536702993859206)
# The Code for America Summit #cfasummit  was an inspiring event. It's amazing to see how much energy,...
# So happy to see Code for America alum company Remix getting so much traction and a new round of funding...
#
# Most similar (score: 0.10306499288773607)
# Live for stream the #CfASummit starting at 2:30 pm PDT.@pahlkadot opens, talking about current @codeforamerica...
# I was on KQED Forum this morning, talking with Michael Krasny about technology and the future of work...
#
# Most similar (score: 0.11521742968329918)
# Who will build the “god platform” for the Internet of Things?The idea that everyone will have a separate...
# There are many directions this article could have gone - the difference in platform philosophy between...
#
# Most similar (score: 0.08881677456732517)
# Top of the new World Trade Center wreathed in clouds. From the 9/11 Memorial
# +Jennifer Pahlka and I share a moment of joy at the top of Warmiwanuska Pass, the highest point on the...
#
# Most similar (score: 0.11757856802063882)
# If we are going to transform government, we need both an inside game and an outside game.The inside...
# This was my favorite piece in this Sunday's New York Times. It's a fascinating article about CBW, a ...
#
# Most similar (score: 0.1268832882361317)
# Fascinating look at the role that various US billionaires play in politics. A quick look at what appears...
# Data can play a great role in advancing sustainability. I'm quoted in this short video from Planet Labs...
#
# Most similar (score: 0.14180028067549078)
# ABC World News covers @HomeDepot credit card data breach, recommends @BillGuard to protect yourself!...
# I reflect on how algorithms affect not just what news we consume, but what news is produced, and how...
#
# Most similar (score: 0.07025785985546606)
# This past weekend, I went up to DRNK Winery (drnkwines.com), the family partnership between Dale and...
# Advice on speechwriting from my 80+ year old Irish aunt: "Try to write a very good first line. And then...
#
# Most similar (score: 0.26504543580680684)
# I'm a huge fan of Dave Hickey, and this piece is well worth reading.
# Well worth reading.  Typical Kevin Kelly insight and level-headedness.
#
# Most similar (score: 0.1126389162192658)
# Not entirely fair to Javascript, but funny:
# I wasn’t entirely happy with my new #NextEconomy piece, Escaping the Superstar Syndrome, so I updated...
#
# Most similar (score: 0.06468675975491622)
# Beautiful trail runs from the slope of Mt. Tam down to the beach at Tennessee Valley. Fantastic views...
# Beautiful exposition by Michael Nielsen on how “cognitive media” helps us think and advance our work...
#
# Most similar (score: 0.08997247953680587)
# The title of this piece doesn't do it justice. The description does better: "This talk discusses how...
# This is a really important piece about open data and platforms.
#
# Most similar (score: 0.04491091516887713)
# I love Warren Buffet's "punch card" analogy. Applied here not just to investing but to live.
# A lot of people have asked me to respond to +Paul Graham’s piece about income inequality. Here it is...
#
# Most similar (score: 0.13358461793794607)
# It's amazing to me that CGI, the company that brought us the healthcare.gov fiasco, has the chutzpah...
# "We need to show every American competent government services they can actually use, services that treat...
#
# Most similar (score: 0.09668243743674099)
# Is anyone else having troubles with Bluetooth on a Moto X?  It connects fine to my car when I make a...
# Painting by Jeannette Charoy at Pamil Fine Arts. Love this one. Thanks for showing it to us, Giancarlo...
#
# Most similar (score: 0.14258474095405949)
# I just did an hour video interview with +Slashdot. Here's what they had to say about it:"We've run...
# Part Two of my NBC Press:Here TV interview from
# Most similar (score: 0.10889746999364991)
# I find it distressing that US politicians (and the rest of world governments) can find hundreds of billions...
# A good example of why you can think of edge.org as TED in text form :-)  It's full of brilliant essays...
#
# Most similar (score: 0.1312219637444354)
# Howtoons is an amazing resource for anyone who wants to inspire the spirit of independence and investigation...
# I love the Howtoons mural at OtherLab's new SF headquarters!
#
# Most similar (score: 0.06596144291880324)
# I love @planetlabs gallery of images of our planet! Daily imaging (rather than annual, or targeted) ...
# I love new sources of trend data about technology adoption. We've used variations of this for years ...
#
# Most similar (score: 0.14045353583708575)
# This is a very cool demo by of musical programming from #OSCON.
# Cool use of Minecraft for conservation!
#
# Most similar (score: 0.14745160575037297)
# I'm super excited to announce that O'Reilly has acquired the 50% of Safari Books Online that we didn't...
# If  told you that any K-12 student in the US can get full access to all O'Reilly books and videos via...
#
# Most similar (score: 0.07881857179265306)
# An excellent demonstration of why Open Access lowers the barriers to knowledge-sharing in science. This...
# This is a really important piece about open data and platforms.
#
# Most similar (score: 0.1171547618003751)
# Why Common Core is Like Healthcare.govDraw a bold line between this piece on the failure of the Common...
# Can We Use Data to Make Better Regulations?Evgeny Morozov either misunderstands or misrepresents the...
#
# Most similar (score: 0.1012737118389142)
# Stories like this make me ashamed to be a US citizen.  We are abdicating our responsibility as citizens...
# Fascinating look at the role that various US billionaires play in politics. A quick look at what appears...
#
# Most similar (score: 0.07747434397861308)
# Back now from a wonderful holiday in Ireland.  It included a "Hawk Walk" in Killarney with Killarney...
# Johnny McGuire, the owner of the wonderful Bricin restaurant in Killarney, told me how moved he was ...
#
# Most similar (score: 0.07970960223945645)
# Kurdish vs Palestinian Strategies for IndependenceThis article makes a really good point, contrasting...
# This is an excellent speech by the former US ambassador to Australia about the world today, ending with...
#
# Most similar (score: 0.04587342160879737)
# It's almost fireworks time in Tulsa!
# Amazing story about digital transformation http://www.codeforamerica.org/blog/2015/11/30/a-new-approach...
#
# Most similar (score: 0.07111056088433854)
# +Lawrence Lessig's MayDay PAC, a crowdfunded super PAC to end the influence of big money in politics...
# “Before Indie.vc, I was focused on raising a million dollars. Now I’m focused on generating a million...
#
# Most similar (score: 0.13248848754510578)
# Fundraiser for Libby Schaaf for Mayor of Oakland at the BlueSprout industrial co working space. Oakland...
# It's wonderful to see the program shaping up for the East Bay Mini Maker Faire in Oakland next Sunday...
#
# Most similar (score: 0.12027154220256675)
#  +Maria Konnikova's NY Times article about the role of time and attention scarcity in the cycle of poverty...
# This was my favorite piece in this Sunday's New York Times. It's a fascinating article about CBW, a ...

# %% [markdown]
# ## Generating a figure to visually display the cosine similarity between documents

# %%
import numpy as np
import matplotlib.pyplot as plt # pip install matplotlib
# %matplotlib inline

max_articles = 15

# Get the titles - the keys to the 'distances' dict
keys = list(distances.keys())

# Extract the article titles
titles = [l[:40].replace('\n',' ')+'...' for l in list(distances.keys())]

n_articles = len(titles) if len(titles) < max_articles else max_articles

# Initialize the matrix of appropriate size to store similarity scores
similarity_matrix = np.zeros((n_articles, n_articles))

# Loop over the cells in the matrix
for i in range(n_articles):
    for j in range(n_articles):
        # Retrieve the cosine distance between articles i and j
        d = distances[keys[i]][keys[j]]
        
        # Store the 'similarity' between articles i and j, defined as 1.0 - distance
        similarity_matrix[i, j] = 1.0 - d


# Create a figure and axes
fig = plt.figure(figsize=(8,8), dpi=300)
ax = fig.add_subplot(111)

# Visualize the matrix with colored squares indicating similarity
ax.matshow(similarity_matrix, cmap='Greys', vmin = 0.0, vmax = 0.2)

# Set regular ticks, one for each article in the collection
ax.set_xticks(range(n_articles))
ax.set_yticks(range(n_articles))

# Set the tick labels as the article titles
ax.set_xticklabels(titles)
ax.set_yticklabels(titles)

# Rotate the labels on the x-axis by 90 degrees
plt.xticks(rotation=90);

# %% [markdown]
# ## Using NLTK to compute bigrams and collocations for a sentence

# %%
import nltk

sentence = "Mr. Green killed Colonel Mustard in the study with the " + \
           "candlestick. Mr. Green is not a very nice fellow."

print([bg for bg in nltk.ngrams(sentence.split(), 2)])
txt = nltk.Text(sentence.split())

txt.collocations()
# Out:
# [('Mr.', 'Green'), ('Green', 'killed'), ('killed', 'Colonel'), ('Colonel', 'Mustard'), ('Mustard', 'in'), ('in', 'the'), ('the', 'study'), ('study', 'with'), ('with', 'the'), ('the', 'candlestick.'), ('candlestick.', 'Mr.'), ('Mr.', 'Green'), ('Green', 'is'), ('is', 'not'), ('not', 'a'), ('a', 'very'), ('very', 'nice'), ('nice', 'fellow.')]
# Mr. Green

# %% [markdown]
# ## Using NLTK to compute collocations in a similar manner to the nltk.Text.collocations demo functionality

# %%
import json
import nltk
from nltk.metrics import association

# Load in human language data from wherever you've saved it
DATA = 'data/timoreilly.json'
data = json.loads(open(DATA).read())

# Number of collocations to find

N = 25

all_tokens = [token for post in data for token in post['content'].lower().split()]

finder = nltk.BigramCollocationFinder.from_words(all_tokens)
finder.apply_freq_filter(2)
finder.apply_word_filter(lambda w: w in nltk.corpus.stopwords.words('english'))
scorer = association.BigramAssocMeasures.jaccard
collocations = finder.nbest(scorer, N)

for collocation in collocations:
    c = ' '.join(collocation)
    print(c)
# Out:
# bottom, “copyright
# brett goldstein
# cabo pulmo
# nbc press:here
# nick hanauer
# press:here tv
# wood fired
# yuval noah
# child welfare
# silicon valley
# +jennifer pahlka
# barre historical
# computational biologist
# drm-free ebooks
# mikey dickerson
# saul griffith
# bay mini
# credit card
# east bay
# on-demand economy,
# white house
# inca trail
# italian granite
# private sector
# weeks ago,
